# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")
df = ticker.history(period="1y")
print(df.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-04-12 00:00:00-04:00  173.441030  177.521767  173.391277  175.720276
# 2024-04-15 00:00:00-04:00  174.535853  175.799888  171.689293  171.878403
# 2024-04-16 00:00:00-04:00  170.942857  172.943405  167.479215  168.584000
# 2024-04-17 00:00:00-04:00  168.812899  169.848004  167.210464  167.210464
# 2024-04-18 00:00:00-04:00  167.240297  167.847430  165.767256  166.254944
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-04-12 00:00:00-04:00  101593300        0.0           0.0
# 2024-04-15 00:00:00-04:00   73531800        0.0           0.0
# 2024-04-16 00:00:00-04:00   73711200        0.0           0.0
# 2024-04-17 00:00:00-04:00   50901200        0.0           0.0
# 2024-04-18 00:00:00-04:00   43122900        0.0           0.0

# %%
df['Daily Return'] = df['Close'].pct_change()

# %%
df['50MA'] = df['Close'].rolling(window=50).mean()
df['200MA'] = df['Close'].rolling(window=200).mean()

# %%
print(df['Close'].describe())
# Out:
# count    251.000000
# mean     219.796212
# std       21.202138
# min      164.224564
# 25%      213.036430
# 50%      224.256287
# 75%      232.753716
# max      258.735504
# Name: Close, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
df['Close'].plot(label='Close')
df['50MA'].plot(label='50-Day MA')
df['200MA'].plot(label='200-Day MA')
plt.legend()
plt.title("AAPL Stock Price and Moving Averages")
plt.show()
