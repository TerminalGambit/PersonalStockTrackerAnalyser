# %% [markdown]
# # 📈 Stock Analysis: Moving Average Indicator
#
# This notebook explores the 50-day Moving Average (50MA) for a chosen stock using Yahoo Finance data. It helps answer the question: **"Should I buy this stock?"** based on trend-following signals.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Choose a Stock and Load Historical Data
#
# We will use the yfinance library to get 1 year of historical price data for a stock (default: Microsoft - MSFT).

# %%
ticker = yf.Ticker("MSFT")
df = ticker.history(period="1y")
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-04-17 00:00:00-04:00  414.088587  415.706242  407.221005  408.719574
# 2024-04-18 00:00:00-04:00  407.518767  408.769230  400.889387  401.206940
# 2024-04-19 00:00:00-04:00  400.968749  402.407775  394.756170  396.095947
# 2024-04-22 00:00:00-04:00  397.048660  399.797691  392.751481  397.921997
# 2024-04-23 00:00:00-04:00  401.177147  405.107165  400.006095  404.481934
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-04-17 00:00:00-04:00  15855500        0.0           0.0
# 2024-04-18 00:00:00-04:00  21029900        0.0           0.0
# 2024-04-19 00:00:00-04:00  30276500        0.0           0.0
# 2024-04-22 00:00:00-04:00  20286900        0.0           0.0
# 2024-04-23 00:00:00-04:00  15734500        0.0           0.0

# %% [markdown]
# ## Step 2: Calculate the 50-Day Moving Average
#
# This smooths out the daily price fluctuations and helps identify overall trends.

# %%
df["50MA"] = df["Close"].rolling(window=50).mean()
df[["Close", "50MA"]].tail()
# Out:
#                                 Close        50MA
# Date
# 2025-04-10 00:00:00-04:00  381.350006  393.888341
# 2025-04-11 00:00:00-04:00  388.450012  393.374150
# 2025-04-14 00:00:00-04:00  387.809998  392.845762
# 2025-04-15 00:00:00-04:00  385.730011  392.358408
# 2025-04-16 00:00:00-04:00  371.609985  391.559711

# %% [markdown]
# ## Step 3: Visualize the Price and Moving Average
#
# We'll plot both the actual closing price and the 50-day moving average.

# %%
plt.figure(figsize=(14, 6))
plt.plot(df["Close"], label="Close Price", linewidth=2)
plt.plot(df["50MA"], label="50-Day Moving Average", linestyle="--")
plt.title("MSFT Close Price & 50-Day MA")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Step 4: Interpretation
#
# - When the stock price is **above the 50MA**, it's often seen as an **uptrend** (bullish).
# - When the price is **below the 50MA**, it may suggest a **downtrend** (bearish).
# - Traders look for **crossovers** where the price moves through the MA line to spot buy/sell signals.
